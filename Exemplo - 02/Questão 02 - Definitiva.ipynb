# %% [markdown]
# ## Questão 02 - Riyadh Levi

# %%
# Importando pacote request externo ao Python
import requests

# %%
# Definindo uma função para efetuar o download da página
def download(url, num_retries=2):
    print('Downloading: ', url)
    page = None
    try:
        response = requests.get(url)
        page = response.text
        if response.status_code >= 400:
            print('Download error:', response.text)
            if num_retries and 500 <= response.status_code < 600:
                return download(url, num_retries - 1)
    except requests.exceptions.RequestExceptions as e:
        print('Download error: ', e.reason)
    return page

# %%
# Importanto pacote externo ao Python, efetuando o download do site e iniciando a 'sopa'
from bs4 import BeautifulSoup
url = 'http://www.imdb.com/chart/boxoffice'
html = download(url)
soup = BeautifulSoup(html, 'html.parser')
# Out:
# Downloading:  http://www.imdb.com/chart/boxoffice

# %%
# Capturando a tag tabela dentro do site e armazenando os dados em uma variável chamada t
t = soup.find('table')

# %%
# Imprimindo a variável
t
# Out:
# <table class="chart full-width" data-caller-name="chart-boxoffice">
# <colgroup>
# <col class="chartTableColumnPoster"/>
# <col class="chartTableColumnTitle"/>
# <col class="chartTableGross"/>
# <col class="chartTableGross"/>
# <col class="chartTableWeeks"/>
# <col class="chartTableColumnWatchlistRibbon"/>
# </colgroup>
# <thead>
# <tr>
# <th></th>
# <th>Title</th>
# <th>Weekend</th>
# <th>Gross</th>
# <th>Weeks</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1" title="Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal">Coco</a>
# </td>
# <td class="ratingColumn">
#                             $49.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$71.2M</span>
# </td>
# <td class="weeksColumn">1</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2380307"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYWVhZjZkYTItOGIwYS00NmRkLWJlYjctMWM0ZjFmMDU4ZjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2" title="Zack Snyder (dir.), Ben Affleck, Gal Gadot">Justice League</a>
# </td>
# <td class="ratingColumn">
#                             $40.7M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$171.5M</span>
# </td>
# <td class="weeksColumn">2</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt0974015"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjFhOWY0OTgtNDkzMC00YWJkLTk1NGEtYWUxNjhmMmQ5ZjYyXkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3" title="Stephen Chbosky (dir.), Jacob Tremblay, Owen Wilson">Wonder</a>
# </td>
# <td class="ratingColumn">
#                             $22.3M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$69.4M</span>
# </td>
# <td class="weeksColumn">2</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2543472"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4" title="Taika Waititi (dir.), Chris Hemsworth, Tom Hiddleston">Thor: Ragnarok</a>
# </td>
# <td class="ratingColumn">
#                             $16.8M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$277.5M</span>
# </td>
# <td class="weeksColumn">4</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3501632"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNDA4Nzc1OTg2OV5BMl5BanBnXkFtZTgwODE3ODgwNDI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5" title="Sean Anders (dir.), Will Ferrell, Mark Wahlberg">Daddy's Home 2</a>
# </td>
# <td class="ratingColumn">
#                             $13.3M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$72.7M</span>
# </td>
# <td class="weeksColumn">3</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt5657846"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNGFmM2NmYjYtMjAwNy00ZDkzLWI3ZWMtOGZhOTRhYzQwMTA0XkEyXkFqcGdeQXVyNzU2MzMyNTI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6" title="Kenneth Branagh (dir.), Kenneth Branagh, Penélope Cruz">Murder on the Orient Express</a>
# </td>
# <td class="ratingColumn">
#                             $13.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$74.2M</span>
# </td>
# <td class="weeksColumn">3</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3402236"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt4587656?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTU4MDQ4NTM2N15BMl5BanBnXkFtZTgwNDM1NTIzMzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt4587656?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7" title="Timothy Reckart (dir.), Steven Yeun, Keegan-Michael Key">The Star</a>
# </td>
# <td class="ratingColumn">
#                             $6.9M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$22.0M</span>
# </td>
# <td class="weeksColumn">2</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt4587656"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt6359956?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwNTA4MDMxNl5BMl5BanBnXkFtZTgwMjE4NjQ0MzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt6359956?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8" title="Jon Lucas (dir.), Mila Kunis, Kristen Bell">A Bad Moms Christmas</a>
# </td>
# <td class="ratingColumn">
#                             $5.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$59.8M</span>
# </td>
# <td class="weeksColumn">4</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt6359956"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt6000478?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMyNjkxMTg2NV5BMl5BanBnXkFtZTgwNjkyNTk0MzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt6000478?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9" title="Dan Gilroy (dir.), Denzel Washington, Colin Farrell">Roman J. Israel, Esq.</a>
# </td>
# <td class="ratingColumn">
#                             $4.5M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$6.3M</span>
# </td>
# <td class="weeksColumn">2</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt6000478"></div></td>
# </td></tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt5027774?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMxNzgwMDUyMl5BMl5BanBnXkFtZTgwMTQ0NTIyNDM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> <td class="titleColumn">
# <a href="/title/tt5027774?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10" title="Martin McDonagh (dir.), Frances McDormand, Woody Harrelson">Three Billboards Outside Ebbing, Missouri</a>
# </td>
# <td class="ratingColumn">
#                             $4.4M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$7.6M</span>
# </td>
# <td class="weeksColumn">3</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt5027774"></div></td>
# </td></tr>
# </tbody>
# </table>

# %%
# Imprimindo o conteúdo da variável
t.contents
# Out:
# ['\n', <colgroup>
#  <col class="chartTableColumnPoster"/>
#  <col class="chartTableColumnTitle"/>
#  <col class="chartTableGross"/>
#  <col class="chartTableGross"/>
#  <col class="chartTableWeeks"/>
#  <col class="chartTableColumnWatchlistRibbon"/>
#  </colgroup>, '\n', <thead>
#  <tr>
#  <th></th>
#  <th>Title</th>
#  <th>Weekend</th>
#  <th>Gross</th>
#  <th>Weeks</th>
#  <th></th>
#  </tr>
#  </thead>, '\n', <tbody>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1" title="Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal">Coco</a>
#  </td>
#  <td class="ratingColumn">
#                              $49.0M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$71.2M</span>
#  </td>
#  <td class="weeksColumn">1</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2380307"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYWVhZjZkYTItOGIwYS00NmRkLWJlYjctMWM0ZjFmMDU4ZjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2" title="Zack Snyder (dir.), Ben Affleck, Gal Gadot">Justice League</a>
#  </td>
#  <td class="ratingColumn">
#                              $40.7M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$171.5M</span>
#  </td>
#  <td class="weeksColumn">2</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt0974015"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjFhOWY0OTgtNDkzMC00YWJkLTk1NGEtYWUxNjhmMmQ5ZjYyXkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3" title="Stephen Chbosky (dir.), Jacob Tremblay, Owen Wilson">Wonder</a>
#  </td>
#  <td class="ratingColumn">
#                              $22.3M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$69.4M</span>
#  </td>
#  <td class="weeksColumn">2</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2543472"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4" title="Taika Waititi (dir.), Chris Hemsworth, Tom Hiddleston">Thor: Ragnarok</a>
#  </td>
#  <td class="ratingColumn">
#                              $16.8M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$277.5M</span>
#  </td>
#  <td class="weeksColumn">4</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3501632"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNDA4Nzc1OTg2OV5BMl5BanBnXkFtZTgwODE3ODgwNDI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5" title="Sean Anders (dir.), Will Ferrell, Mark Wahlberg">Daddy's Home 2</a>
#  </td>
#  <td class="ratingColumn">
#                              $13.3M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$72.7M</span>
#  </td>
#  <td class="weeksColumn">3</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt5657846"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNGFmM2NmYjYtMjAwNy00ZDkzLWI3ZWMtOGZhOTRhYzQwMTA0XkEyXkFqcGdeQXVyNzU2MzMyNTI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6" title="Kenneth Branagh (dir.), Kenneth Branagh, Penélope Cruz">Murder on the Orient Express</a>
#  </td>
#  <td class="ratingColumn">
#                              $13.0M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$74.2M</span>
#  </td>
#  <td class="weeksColumn">3</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3402236"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt4587656?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTU4MDQ4NTM2N15BMl5BanBnXkFtZTgwNDM1NTIzMzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt4587656?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7" title="Timothy Reckart (dir.), Steven Yeun, Keegan-Michael Key">The Star</a>
#  </td>
#  <td class="ratingColumn">
#                              $6.9M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$22.0M</span>
#  </td>
#  <td class="weeksColumn">2</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt4587656"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt6359956?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwNTA4MDMxNl5BMl5BanBnXkFtZTgwMjE4NjQ0MzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt6359956?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8" title="Jon Lucas (dir.), Mila Kunis, Kristen Bell">A Bad Moms Christmas</a>
#  </td>
#  <td class="ratingColumn">
#                              $5.0M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$59.8M</span>
#  </td>
#  <td class="weeksColumn">4</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt6359956"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt6000478?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMyNjkxMTg2NV5BMl5BanBnXkFtZTgwNjkyNTk0MzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt6000478?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9" title="Dan Gilroy (dir.), Denzel Washington, Colin Farrell">Roman J. Israel, Esq.</a>
#  </td>
#  <td class="ratingColumn">
#                              $4.5M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$6.3M</span>
#  </td>
#  <td class="weeksColumn">2</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt6000478"></div></td>
#  </td></tr>
#  <tr>
#  <td class="posterColumn">
#  <a href="/title/tt5027774?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMxNzgwMDUyMl5BMl5BanBnXkFtZTgwMTQ0NTIyNDM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> <td class="titleColumn">
#  <a href="/title/tt5027774?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0TR32B26H3B8SVQR59V4&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10" title="Martin McDonagh (dir.), Frances McDormand, Woody Harrelson">Three Billboards Outside Ebbing, Missouri</a>
#  </td>
#  <td class="ratingColumn">
#                              $4.4M
#                      </td>
#  <td class="ratingColumn">
#  <span class="secondaryInfo">$7.6M</span>
#  </td>
#  <td class="weeksColumn">3</td>
#  <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt5027774"></div></td>
#  </td></tr>
#  </tbody>, '\n']

# %%
print(t.find_all(class_ = 'titleColumn')[3].get_text())
print(t.find_all(class_ = 'ratingColumn')[6].get_text())
print(t.find_all(class_ = 'secondaryInfo')[3].get_text())
print(t.find_all(class_ = 'weeksColumn')[3].get_text())
# Out:
# Thor: Ragnarok
#
#
#                             $16.8M
#
# $277.5M
# 4

# %%
qtd = len(t.find_all(class_ = 'titleColumn'))

# %%
position = 0
list_dict = []

# %%
while position < qtd:
    titulo     = t.find_all(class_ = 'titleColumn')[position].get_text().replace('\n','')
    fim_de_semana = t.find_all(class_ = 'ratingColumn')[position*2].get_text().replace(' ', '').replace('\n','')
    total = t.find_all(class_ = 'secondaryInfo')[position].get_text()
    semanas = t.find_all(class_ = 'weeksColumn')[position].get_text()
    filme_dic = {'Título': titulo, 'Fim de semana': fim_de_semana, 'Total': total, 'Semanas': semanas}
    list_dict.append(filme_dic)
    position+=1

# %%
list_dict
# Out:
# [{'Fim de semana': '$49.0M',
#   'Semanas': '1',
#   'Total': '$71.2M',
#   'Título': 'Coco'},
#  {'Fim de semana': '$40.7M',
#   'Semanas': '2',
#   'Total': '$171.5M',
#   'Título': 'Justice League'},
#  {'Fim de semana': '$22.3M',
#   'Semanas': '2',
#   'Total': '$69.4M',
#   'Título': 'Wonder'},
#  {'Fim de semana': '$16.8M',
#   'Semanas': '4',
#   'Total': '$277.5M',
#   'Título': 'Thor: Ragnarok'},
#  {'Fim de semana': '$13.3M',
#   'Semanas': '3',
#   'Total': '$72.7M',
#   'Título': "Daddy's Home 2"},
#  {'Fim de semana': '$13.0M',
#   'Semanas': '3',
#   'Total': '$74.2M',
#   'Título': 'Murder on the Orient Express'},
#  {'Fim de semana': '$6.9M',
#   'Semanas': '2',
#   'Total': '$22.0M',
#   'Título': 'The Star'},
#  {'Fim de semana': '$5.0M',
#   'Semanas': '4',
#   'Total': '$59.8M',
#   'Título': 'A Bad Moms Christmas'},
#  {'Fim de semana': '$4.5M',
#   'Semanas': '2',
#   'Total': '$6.3M',
#   'Título': 'Roman J. Israel, Esq.'},
#  {'Fim de semana': '$4.4M',
#   'Semanas': '3',
#   'Total': '$7.6M',
#   'Título': 'Three Billboards Outside Ebbing, Missouri'}]

# %%
# Importa pacote externo ao Python
import pandas as pd

# %%
# Cria uma tabela recebendo a lista de dicionários como parâmetro e a ordem das colunas passa a ser 'Nome' e 'Avaliação'
df = pd.DataFrame(list_dict, columns=['Título','Fim de semana', 'Total', 'Semanas'])
df.index = df['Título']
del df['Título']
df
# Out:
#                                           Fim de semana    Total Semanas
# Título
# Coco                                             $49.0M   $71.2M       1
# Justice League                                   $40.7M  $171.5M       2
# Wonder                                           $22.3M   $69.4M       2
# Thor: Ragnarok                                   $16.8M  $277.5M       4
# Daddy's Home 2                                   $13.3M   $72.7M       3
# Murder on the Orient Express                     $13.0M   $74.2M       3
# The Star                                          $6.9M   $22.0M       2
# A Bad Moms Christmas                              $5.0M   $59.8M       4
# Roman J. Israel, Esq.                             $4.5M    $6.3M       2
# Three Billboards Outside Ebbing, Missouri         $4.4M    $7.6M       3

# %%
df.to_csv('questao_02_hard_panda.csv')

# %%
df.to_excel('questao_02_hard_panda.xlsx')
